# %%
import pickle
import pickletools
import utils
import matplotlib.pyplot as plt
import numpy as np 
from scipy.stats import t

# %% [markdown]
# # Single Data

# %% [markdown]
# ### Note that this needs the experiment to be finished
# ### The graph only considers UEs that involves in handover. Some UEs lost connections without handover will not be here.

# %%
def separate_waiting_time(result_waiting_time, result_success_or_failure):
    result_waiting_time_success = []
    result_waiting_time_failure = []
    for id in result_waiting_time:
        if result_success_or_failure[id]:
            result_waiting_time_success.append(result_waiting_time[id])
        else:
            result_waiting_time_failure.append(result_waiting_time[id])
    return result_waiting_time_success, result_waiting_time_failure

def stat(values, confidence):
    v = np.array(values)
    m = v.mean()
    s = v.std()
    dof = len(v) - 1
    t_crit = np.abs(t.ppf((1-confidence)/2,dof))
    c = (m-s*t_crit/np.sqrt(len(v)), m+s*t_crit/np.sqrt(len(v)))
    print(f"  # Confidence Interval: {round(m,2)}±{round(s*t_crit/np.sqrt(len(v)),2)}")
    
def gives_result(path,sat_id, draw=False):
    with open(path, 'rb') as inp:
        data = pickle.load(inp)
    res = {}
    for ue_id in data.UE_time_stamp:
        UE_time = data.UE_time_stamp[ue_id]
        for each in UE_time:
            if each['from'] == sat_id:
                res[ue_id] = each
    res_waiting_time = {}
    res_success_or_failure = {}

    for id in res:
        r = res[id]
        res_waiting_time[id] = (r['timestamp'][-1] - r['timestamp'][0])
        res_success_or_failure[id] = r['isSuccess']
        
    waiting_time_success, waiting_time_failure = separate_waiting_time(res_waiting_time, res_success_or_failure)

    print(f"Success Rate: {len(waiting_time_success)}/{len(waiting_time_failure) + len(waiting_time_success)} = {100*len(waiting_time_success)/(len(waiting_time_failure) + len(waiting_time_success))}%")
    if len(waiting_time_success) != 0:
        print(f"Success UE waiting time: ")
        stat(waiting_time_success,0.95)
    if len(waiting_time_failure) != 0:
        print(f"Failure UE waiting time: ")
        stat(waiting_time_failure,0.95)

    total = data.cumulative_total_messages[sat_id][-1]
    UE_message = data.cumulative_message_from_UE_measurement[sat_id][-1]
    UE_retransmit = data.cumulative_message_from_UE_retransmit[sat_id][-1]
    satellite = data.cumulative_message_from_satellite[sat_id][-1]
    dropped = data.cumulative_message_from_dropped[sat_id][-1]
    
    

    print(f"Total message received: {total}")
    print(f" requests received from UE (% to total messages): {(UE_message + UE_retransmit)} ({round(100*(UE_message + UE_retransmit)/total, 2)}%)")
    print(f" messages received from satellite (% to total messages): {(satellite)} ({round(100*(satellite)/total, 2)}%)")
    print(f" dropped messages (% to UE messages) {dropped} ({round(100 * dropped / (total), 2)}%)")
    
    if draw:
        fig, axes = plt.subplots(1, 3, figsize=(36*0.8, 12*0.8))
        size = 0.3
        
        UE_positions = data.UE_positions
        pop_keys = []
        for id in UE_positions:
            if id not in res:
                pop_keys.append(id)
        for key in pop_keys:
            UE_positions.pop(key)
            
        # Combined Graph
        pos_x = np.array([UE_positions[id][0] for id in UE_positions])
        pos_y = np.array([UE_positions[id][1] for id in UE_positions])
        res_success_or_failure_array = np.array([res_success_or_failure[id] for id in UE_positions])
        colors = np.where(res_success_or_failure_array, 'g', 'red')
        axes[0].scatter(x=pos_x, y=pos_y, c=colors, alpha=1, s = size)
        axes[0].set_facecolor("black")
        
        # Success
        success_UE_positions = {}
        for id in UE_positions:
            if res_success_or_failure[id]:
                success_UE_positions[id] = UE_positions[id]
        if len(success_UE_positions) != 0:
            pos_x = np.array([success_UE_positions[id][0] for id in success_UE_positions])
            pos_y = np.array([success_UE_positions[id][1] for id in success_UE_positions])
            axes[1].scatter(x=pos_x, y=pos_y, c='g', alpha=1, s = size)
            axes[1].set_facecolor("black")
        
        # Failure
        failure_UE_positions = {}
        for id in UE_positions:
            if not res_success_or_failure[id]:
                failure_UE_positions[id] = UE_positions[id]
        if len(failure_UE_positions) != 0:
            pos_x = np.array([failure_UE_positions[id][0] for id in failure_UE_positions])
            pos_y = np.array([failure_UE_positions[id][1] for id in failure_UE_positions])
            axes[2].scatter(x=pos_x, y=pos_y, c='r', alpha=1, s = size)
            axes[2].set_facecolor("black")
    # Collect this experiment
    interval = 200
    l = np.array(data.cumulative_total_messages[sat_id])
    dynamictotal = l[interval:] - l[:-interval]

    l = np.array(data.cumulative_message_from_dropped[sat_id])
    dynamicdrop = l[interval:] - l[:-interval]
    f = {}
    f['total'] = total
    f['totalUE'] = UE_message + UE_retransmit
    f['totaldrop'] = dropped
    f['sUE'] = waiting_time_success
    f['fUE'] = waiting_time_failure
    f['dynamictotal'] = dynamictotal
    f['dynamicdrop'] = dynamicdrop

    #final = finaldata(total, UE_message + UE_retransmit, dropped,waiting_time_success,waiting_time_failure, dynamictotal, dynamicdrop)
    return f

# %%
seeds = [10, 20, 30, 40, 50]
for seed in seeds:   
    f10000 = gives_result(f'../seed{seed}/main/10000/graph_datadata_object.pkl', 1, False)
    f20000 = gives_result(f'../seed{seed}/main/20000/graph_datadata_object.pkl', 1, False)
    f30000 = gives_result(f'../seed{seed}/main/30000/graph_datadata_object.pkl', 1, False)
    f40000 = gives_result(f'../seed{seed}/main/40000/graph_datadata_object.pkl', 1, False)
    f50000 = gives_result(f'../seed{seed}/main/50000/graph_datadata_object.pkl', 1, False)
    f60000 = gives_result(f'../seed{seed}/main/60000/graph_datadata_object.pkl', 1, False)
    f70000 = gives_result(f'../seed{seed}/main/70000/graph_datadata_object.pkl', 1, False)
    d = {}
    d['10000'] = f10000
    d['20000'] = f20000
    d['30000'] = f30000
    d['40000'] = f40000
    d['50000'] = f50000
    d['60000'] = f60000
    d['70000'] = f70000
    with open(f'{seed}main.pickle', 'wb') as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 8.99±0.0
# Total message received: 30000
#  requests received from UE (% to total messages): 10000 (33.33%)
#  messages received from satellite (% to total messages): 10000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 9.24±0.0
# Total message received: 60000
#  requests received from UE (% to total messages): 20000 (33.33%)
#  messages received from satellite (% to total messages): 20000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 34.07±0.22
# Total message received: 106889
#  requests received from UE (% to total messages): 46889 (43.87%)
#  messages received from satellite (% to total messages): 30000 (28.07%)
#  dropped messages (% to UE messages) 2071 (1.94%)
# Success Rate: 32487/40000 = 81.2175%
# Success UE waiting time:
#   # Confidence Interval: 212.7±1.56
# Failure UE waiting time:
#   # Confidence Interval: 856.39±7.51
# Total message received: 412940
#  requests received from UE (% to total messages): 347849 (84.24%)
#  messages received from satellite (% to total messages): 32604 (7.9%)
#  dropped messages (% to UE messages) 307595 (74.49%)
# Success Rate: 33243/50000 = 66.486%
# Success UE waiting time:
#   # Confidence Interval: 243.17±1.6
# Failure UE waiting time:
#   # Confidence Interval: 888.64±4.78
# Total message received: 600112
#  requests received from UE (% to total messages): 533517 (88.9%)
#  messages received from satellite (% to total messages): 33352 (5.56%)
#  dropped messages (% to UE messages) 493471 (82.23%)
# Success Rate: 33726/60000 = 56.21%
# Success UE waiting time:
#   # Confidence Interval: 263.44±1.61
# Failure UE waiting time:
#   # Confidence Interval: 900.89±3.72
# Total message received: 777319
#  requests received from UE (% to total messages): 709752 (91.31%)
#  messages received from satellite (% to total messages): 33841 (4.35%)
#  dropped messages (% to UE messages) 669692 (86.15%)
# Success Rate: 34053/70000 = 48.64714285714286%
# Success UE waiting time:
#   # Confidence Interval: 274.58±1.6
# Failure UE waiting time:
#   # Confidence Interval: 908.75±3.13
# Total message received: 943400
#  requests received from UE (% to total messages): 875185 (92.77%)
#  messages received from satellite (% to total messages): 34162 (3.62%)
#  dropped messages (% to UE messages) 835590 (88.57%)
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 8.99±0.0
# Total message received: 30000
#  requests received from UE (% to total messages): 10000 (33.33%)
#  messages received from satellite (% to total messages): 10000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 9.24±0.0
# Total message received: 60000
#  requests received from UE (% to total messages): 20000 (33.33%)
#  messages received from satellite (% to total messages): 20000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 23.85±0.16
# Total message received: 97403
#  requests received from UE (% to total messages): 37403 (38.4%)
#  messages received from satellite (% to total messages): 30000 (30.8%)
#  dropped messages (% to UE messages) 51 (0.05%)
# Success Rate: 32577/40000 = 81.4425%
# Success UE waiting time:
#   # Confidence Interval: 212.55±1.55
# Failure UE waiting time:
#   # Confidence Interval: 857.47±7.55
# Total message received: 412380
#  requests received from UE (% to total messages): 347122 (84.18%)
#  messages received from satellite (% to total messages): 32681 (7.92%)
#  dropped messages (% to UE messages) 306861 (74.41%)
# Success Rate: 33330/50000 = 66.66%
# Success UE waiting time:
#   # Confidence Interval: 248.51±1.6
# Failure UE waiting time:
#   # Confidence Interval: 887.71±4.76
# Total message received: 605308
#  requests received from UE (% to total messages): 538528 (88.97%)
#  messages received from satellite (% to total messages): 33450 (5.53%)
#  dropped messages (% to UE messages) 498183 (82.3%)
# Success Rate: 33812/60000 = 56.35333333333333%
# Success UE waiting time:
#   # Confidence Interval: 263.81±1.6
# Failure UE waiting time:
#   # Confidence Interval: 902.15±3.71
# Total message received: 777809
#  requests received from UE (% to total messages): 710083 (91.29%)
#  messages received from satellite (% to total messages): 33914 (4.36%)
#  dropped messages (% to UE messages) 670231 (86.17%)
# Success Rate: 34154/70000 = 48.79142857142857%
# Success UE waiting time:
#   # Confidence Interval: 274.97±1.61
# Failure UE waiting time:
#   # Confidence Interval: 911.1±3.13
# Total message received: 943574
#  requests received from UE (% to total messages): 875134 (92.75%)
#  messages received from satellite (% to total messages): 34286 (3.63%)
#  dropped messages (% to UE messages) 835721 (88.57%)
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 8.99±0.0
# Total message received: 30000
#  requests received from UE (% to total messages): 10000 (33.33%)
#  messages received from satellite (% to total messages): 10000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 9.24±0.0
# Total message received: 60000
#  requests received from UE (% to total messages): 20000 (33.33%)
#  messages received from satellite (% to total messages): 20000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 33.78±0.21
# Total message received: 107674
#  requests received from UE (% to total messages): 47674 (44.28%)
#  messages received from satellite (% to total messages): 30000 (27.86%)
#  dropped messages (% to UE messages) 448 (0.42%)
# Success Rate: 32465/40000 = 81.1625%
# Success UE waiting time:
#   # Confidence Interval: 216.12±1.55
# Failure UE waiting time:
#   # Confidence Interval: 858.45±7.48
# Total message received: 416580
#  requests received from UE (% to total messages): 351554 (84.39%)
#  messages received from satellite (% to total messages): 32561 (7.82%)
#  dropped messages (% to UE messages) 311239 (74.71%)
# Success Rate: 33231/50000 = 66.462%
# Success UE waiting time:
#   # Confidence Interval: 247.47±1.6
# Failure UE waiting time:
#   # Confidence Interval: 887.32±4.78
# Total message received: 604330
#  requests received from UE (% to total messages): 537757 (88.98%)
#  messages received from satellite (% to total messages): 33342 (5.52%)
#  dropped messages (% to UE messages) 497798 (82.37%)
# Success Rate: 33713/60000 = 56.18833333333333%
# Success UE waiting time:
#   # Confidence Interval: 264.28±1.6
# Failure UE waiting time:
#   # Confidence Interval: 904.89±3.69
# Total message received: 779256
#  requests received from UE (% to total messages): 711699 (91.33%)
#  messages received from satellite (% to total messages): 33844 (4.34%)
#  dropped messages (% to UE messages) 671756 (86.2%)
# Success Rate: 34071/70000 = 48.67285714285714%
# Success UE waiting time:
#   # Confidence Interval: 274.83±1.61
# Failure UE waiting time:
#   # Confidence Interval: 911.21±3.12
# Total message received: 943730
#  requests received from UE (% to total messages): 875479 (92.77%)
#  messages received from satellite (% to total messages): 34180 (3.62%)
#  dropped messages (% to UE messages) 835871 (88.57%)
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 8.99±0.0
# Total message received: 30000
#  requests received from UE (% to total messages): 10000 (33.33%)
#  messages received from satellite (% to total messages): 10000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 9.23±0.0
# Total message received: 60000
#  requests received from UE (% to total messages): 20000 (33.33%)
#  messages received from satellite (% to total messages): 20000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 26.95±0.13
# Total message received: 103537
#  requests received from UE (% to total messages): 43537 (42.05%)
#  messages received from satellite (% to total messages): 30000 (28.98%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 32483/40000 = 81.2075%
# Success UE waiting time:
#   # Confidence Interval: 214.54±1.56
# Failure UE waiting time:
#   # Confidence Interval: 862.99±7.46
# Total message received: 414569
#  requests received from UE (% to total messages): 349510 (84.31%)
#  messages received from satellite (% to total messages): 32576 (7.86%)
#  dropped messages (% to UE messages) 309357 (74.62%)
# Success Rate: 33272/50000 = 66.544%
# Success UE waiting time:
#   # Confidence Interval: 246.75±1.6
# Failure UE waiting time:
#   # Confidence Interval: 888.98±4.8
# Total message received: 603769
#  requests received from UE (% to total messages): 537126 (88.96%)
#  messages received from satellite (% to total messages): 33371 (5.53%)
#  dropped messages (% to UE messages) 496989 (82.31%)
# Success Rate: 33759/60000 = 56.265%
# Success UE waiting time:
#   # Confidence Interval: 262.57±1.6
# Failure UE waiting time:
#   # Confidence Interval: 899.92±3.72
# Total message received: 776420
#  requests received from UE (% to total messages): 708807 (91.29%)
#  messages received from satellite (% to total messages): 33854 (4.36%)
#  dropped messages (% to UE messages) 668866 (86.15%)
# Success Rate: 34077/70000 = 48.68142857142857%
# Success UE waiting time:
#   # Confidence Interval: 274.39±1.6
# Failure UE waiting time:
#   # Confidence Interval: 908.99±3.13
# Total message received: 942911
#  requests received from UE (% to total messages): 874633 (92.76%)
#  messages received from satellite (% to total messages): 34201 (3.63%)
#  dropped messages (% to UE messages) 835152 (88.57%)
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 8.99±0.0
# Total message received: 30000
#  requests received from UE (% to total messages): 10000 (33.33%)
#  messages received from satellite (% to total messages): 10000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 9.24±0.0
# Total message received: 60000
#  requests received from UE (% to total messages): 20000 (33.33%)
#  messages received from satellite (% to total messages): 20000 (33.33%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 21.05±0.12
# Total message received: 94798
#  requests received from UE (% to total messages): 34798 (36.71%)
#  messages received from satellite (% to total messages): 30000 (31.65%)
#  dropped messages (% to UE messages) 0 (0.0%)
# Success Rate: 32479/40000 = 81.1975%
# Success UE waiting time:
#   # Confidence Interval: 215.27±1.56
# Failure UE waiting time:
#   # Confidence Interval: 857.1±7.49
# Total message received: 416308
#  requests received from UE (% to total messages): 351247 (84.37%)
#  messages received from satellite (% to total messages): 32582 (7.83%)
#  dropped messages (% to UE messages) 311053 (74.72%)
# Success Rate: 33309/50000 = 66.618%
# Success UE waiting time:
#   # Confidence Interval: 245.08±1.6
# Failure UE waiting time:
#   # Confidence Interval: 886.56±4.78
# Total message received: 601389
#  requests received from UE (% to total messages): 534661 (88.9%)
#  messages received from satellite (% to total messages): 33419 (5.56%)
#  dropped messages (% to UE messages) 494522 (82.23%)
# Success Rate: 33776/60000 = 56.29333333333334%
# Success UE waiting time:
#   # Confidence Interval: 264.77±1.61
# Failure UE waiting time:
#   # Confidence Interval: 899.89±3.73
# Total message received: 778048
#  requests received from UE (% to total messages): 710375 (91.3%)
#  messages received from satellite (% to total messages): 33897 (4.36%)
#  dropped messages (% to UE messages) 670472 (86.17%)
# Success Rate: 34118/70000 = 48.74%
# Success UE waiting time:
#   # Confidence Interval: 273.58±1.6
# Failure UE waiting time:
#   # Confidence Interval: 906.87±3.14
# Total message received: 941914
#  requests received from UE (% to total messages): 873557 (92.74%)
#  messages received from satellite (% to total messages): 34239 (3.64%)
#  dropped messages (% to UE messages) 833809 (88.52%)
