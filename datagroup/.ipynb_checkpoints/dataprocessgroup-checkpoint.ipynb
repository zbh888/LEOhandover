# %%
import pickle
import pickletools
import utils
import matplotlib.pyplot as plt
import numpy as np 
from scipy.stats import t

# %% [markdown]
# # Single Data

# %% [markdown]
# ### Note that this needs the experiment to be finished
# ### The graph only considers UEs that involves in handover. Some UEs lost connections without handover will not be here.

# %%
def separate_waiting_time(result_waiting_time, result_success_or_failure):
    result_waiting_time_success = []
    result_waiting_time_failure = []
    for id in result_waiting_time:
        if result_success_or_failure[id]:
            result_waiting_time_success.append(result_waiting_time[id])
        else:
            result_waiting_time_failure.append(result_waiting_time[id])
    return result_waiting_time_success, result_waiting_time_failure

def stat(values, confidence):
    v = np.array(values)
    m = v.mean()
    s = v.std()
    dof = len(v) - 1
    t_crit = np.abs(t.ppf((1-confidence)/2,dof))
    c = (m-s*t_crit/np.sqrt(len(v)), m+s*t_crit/np.sqrt(len(v)))
    print(f"  # Confidence Interval: {round(m,2)}±{round(s*t_crit/np.sqrt(len(v)),2)}")
    
def gives_result(path,sat_id, draw=False):
    with open(path, 'rb') as inp:
        data = pickle.load(inp)
    res = {}
    for ue_id in data.UE_time_stamp:
        UE_time = data.UE_time_stamp[ue_id]
        for each in UE_time:
            if each['from'] == sat_id:
                res[ue_id] = each
    res_waiting_time = {}
    res_success_or_failure = {}

    for id in res:
        r = res[id]
        res_waiting_time[id] = (r['timestamp'][-1] - r['timestamp'][0])
        res_success_or_failure[id] = r['isSuccess']
        
    waiting_time_success, waiting_time_failure = separate_waiting_time(res_waiting_time, res_success_or_failure)

    print(f"Success Rate: {len(waiting_time_success)}/{len(waiting_time_failure) + len(waiting_time_success)} = {100*len(waiting_time_success)/(len(waiting_time_failure) + len(waiting_time_success))}%")
    if len(waiting_time_success) != 0:
        print(f"Success UE waiting time: ")
        stat(waiting_time_success,0.95)
    if len(waiting_time_failure) != 0:
        print(f"Failure UE waiting time: ")
        stat(waiting_time_failure,0.95)

    total = data.cumulative_total_messages[sat_id][-1]
    UE_message = data.cumulative_message_from_UE_measurement[sat_id][-1]
    UE_retransmit = data.cumulative_message_from_UE_retransmit[sat_id][-1]
    group_UE_message = data.cumulative_message_from_UE_Group[sat_id][-1]
    group_UE_message_retransmit = data.cumulative_message_from_UE_Group_retransmit[1][-1]
    
    satellite = data.cumulative_message_from_satellite[sat_id][-1]
    
    dropped_from_group = data.cumulative_message_from_dropped_from_group[sat_id][-1]
    dropped_from_non_group = data.cumulative_message_from_dropped_from_non_group[sat_id][-1]

    UE = UE_message + UE_retransmit + group_UE_message + group_UE_message_retransmit
    dropped = dropped_from_group + dropped_from_non_group

    print(f"Total message received: {total}")
    print(f" messages received from satellite (% to total messages): {(satellite)} ({round(100*(satellite)/total, 2)}%)")
    print(f" requests received from UE (% to total messages): {(UE)} ({round(100*(UE)/total, 2)}%)")
    print(f"   # dropped messages (% to UE messages) {dropped} ({round(100 * dropped / (total), 2)}%)")
    print(f"   # group messages (% to UE) {round((group_UE_message + group_UE_message_retransmit)/UE * 100, 2)}%")
    
    if draw:
        fig, axes = plt.subplots(1, 3, figsize=(36*0.8, 12*0.8))
        size = 0.3
        
        UE_positions = data.UE_positions
        pop_keys = []
        for id in UE_positions:
            if id not in res:
                pop_keys.append(id)
        for key in pop_keys:
            UE_positions.pop(key)
            
        # Combined Graph
        pos_x = np.array([UE_positions[id][0] for id in UE_positions])
        pos_y = np.array([UE_positions[id][1] for id in UE_positions])
        res_success_or_failure_array = np.array([res_success_or_failure[id] for id in UE_positions])
        colors = np.where(res_success_or_failure_array, 'g', 'red')
        axes[0].scatter(x=pos_x, y=pos_y, c=colors, alpha=1, s = size)
        axes[0].set_facecolor("black")
        
        # Success
        success_UE_positions = {}
        for id in UE_positions:
            if res_success_or_failure[id]:
                success_UE_positions[id] = UE_positions[id]
        if len(success_UE_positions) != 0:
            pos_x = np.array([success_UE_positions[id][0] for id in success_UE_positions])
            pos_y = np.array([success_UE_positions[id][1] for id in success_UE_positions])
            axes[1].scatter(x=pos_x, y=pos_y, c='g', alpha=1, s = size)
            axes[1].set_facecolor("black")
        
        # Failure
        failure_UE_positions = {}
        for id in UE_positions:
            if not res_success_or_failure[id]:
                failure_UE_positions[id] = UE_positions[id]
        if len(failure_UE_positions) != 0:
            pos_x = np.array([failure_UE_positions[id][0] for id in failure_UE_positions])
            pos_y = np.array([failure_UE_positions[id][1] for id in failure_UE_positions])
            axes[2].scatter(x=pos_x, y=pos_y, c='r', alpha=1, s = size)
            axes[2].set_facecolor("black")
    interval = 200
    l = np.array(data.cumulative_total_messages[sat_id])
    dynamictotal = l[interval:] - l[:-interval]

    l = (np.array(data.cumulative_message_from_dropped_from_group[sat_id])
        +np.array(data.cumulative_message_from_dropped_from_non_group[sat_id]))
    dynamicdrop = l[interval:] - l[:-interval]
    f = {}
    f['total'] = total
    f['totalUE'] = UE
    f['totaldrop'] = dropped
    f['sUE'] = waiting_time_success
    f['fUE'] = waiting_time_failure
    f['dynamictotal'] = dynamictotal
    f['dynamicdrop'] = dynamicdrop

    #final = finaldata(total, UE_message + UE_retransmit, dropped,waiting_time_success,waiting_time_failure, dynamictotal, dynamicdrop)
    return f

# %%
seeds = [10, 20, 30, 40, 50]
for seed in seeds:   
    f10000 = gives_result(f'../seed{seed}/group/10000/graph_datadata_object.pkl', 1, False)
    f20000 = gives_result(f'../seed{seed}/group/20000/graph_datadata_object.pkl', 1, False)
    f30000 = gives_result(f'../seed{seed}/group/30000/graph_datadata_object.pkl', 1, False)
    f40000 = gives_result(f'../seed{seed}/group/40000/graph_datadata_object.pkl', 1, False)
    f50000 = gives_result(f'../seed{seed}/group/50000/graph_datadata_object.pkl', 1, False)
    f60000 = gives_result(f'../seed{seed}/group/60000/graph_datadata_object.pkl', 1, False)
    f70000 = gives_result(f'../seed{seed}/group/70000/graph_datadata_object.pkl', 1, False)
    d = {}
    d['10000'] = f10000
    d['20000'] = f20000
    d['30000'] = f30000
    d['40000'] = f40000
    d['50000'] = f50000
    d['60000'] = f60000
    d['70000'] = f70000
    with open(f'{seed}group.pickle', 'wb') as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 16.36±0.41
# Total message received: 16760
#  messages received from satellite (% to total messages): 1980 (11.81%)
#  requests received from UE (% to total messages): 4780 (28.52%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 87.87%
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 19.39±0.32
# Total message received: 27194
#  messages received from satellite (% to total messages): 2052 (7.55%)
#  requests received from UE (% to total messages): 5142 (18.91%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 90.2%
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 23.15±0.29
# Total message received: 37164
#  messages received from satellite (% to total messages): 1973 (5.31%)
#  requests received from UE (% to total messages): 5191 (13.97%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 92.99%
# Success Rate: 40000/40000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 25.71±0.27
# Total message received: 47394
#  messages received from satellite (% to total messages): 2023 (4.27%)
#  requests received from UE (% to total messages): 5371 (11.33%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 93.61%
# Success Rate: 50000/50000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 73.27±0.48
# Total message received: 67648
#  messages received from satellite (% to total messages): 4920 (7.27%)
#  requests received from UE (% to total messages): 12728 (18.82%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 92.61%
# Success Rate: 55753/60000 = 92.92166666666667%
# Success UE waiting time:
#   # Confidence Interval: 331.33±2.07
# Failure UE waiting time:
#   # Confidence Interval: 434.15±4.57
# Total message received: 121953
#  messages received from satellite (% to total messages): 18928 (15.52%)
#  requests received from UE (% to total messages): 47272 (38.76%)
#    # dropped messages (% to UE messages) 1427 (1.17%)
#    # group messages (% to UE) 91.78%
# Success Rate: 57859/70000 = 82.65571428571428%
# Success UE waiting time:
#   # Confidence Interval: 481.23±2.66
# Failure UE waiting time:
#   # Confidence Interval: 565.71±3.74
# Total message received: 139202
#  messages received from satellite (% to total messages): 22485 (16.15%)
#  requests received from UE (% to total messages): 58858 (42.28%)
#    # dropped messages (% to UE messages) 3802 (2.73%)
#    # group messages (% to UE) 92.61%
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 16.17±0.4
# Total message received: 16502
#  messages received from satellite (% to total messages): 1713 (10.38%)
#  requests received from UE (% to total messages): 4789 (29.02%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 96.35%
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 19.4±0.33
# Total message received: 26608
#  messages received from satellite (% to total messages): 1671 (6.28%)
#  requests received from UE (% to total messages): 4937 (18.55%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 99.23%
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 23.19±0.29
# Total message received: 36826
#  messages received from satellite (% to total messages): 1776 (4.82%)
#  requests received from UE (% to total messages): 5050 (13.71%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 97.25%
# Success Rate: 40000/40000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 25.73±0.27
# Total message received: 47094
#  messages received from satellite (% to total messages): 1872 (3.98%)
#  requests received from UE (% to total messages): 5222 (11.09%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 96.34%
# Success Rate: 50000/50000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 59.28±0.41
# Total message received: 64414
#  messages received from satellite (% to total messages): 3893 (6.04%)
#  requests received from UE (% to total messages): 10521 (16.33%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 94.78%
# Success Rate: 55898/60000 = 93.16333333333333%
# Success UE waiting time:
#   # Confidence Interval: 335.22±2.04
# Failure UE waiting time:
#   # Confidence Interval: 432.74±4.51
# Total message received: 121409
#  messages received from satellite (% to total messages): 18230 (15.02%)
#  requests received from UE (% to total messages): 47281 (38.94%)
#    # dropped messages (% to UE messages) 1363 (1.12%)
#    # group messages (% to UE) 93.65%
# Success Rate: 58132/70000 = 83.04571428571428%
# Success UE waiting time:
#   # Confidence Interval: 479.13±2.67
# Failure UE waiting time:
#   # Confidence Interval: 568.3±3.76
# Total message received: 137714
#  messages received from satellite (% to total messages): 21781 (15.82%)
#  requests received from UE (% to total messages): 57801 (41.97%)
#    # dropped messages (% to UE messages) 3510 (2.55%)
#    # group messages (% to UE) 94.44%
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 16.04±0.4
# Total message received: 16488
#  messages received from satellite (% to total messages): 1723 (10.45%)
#  requests received from UE (% to total messages): 4765 (28.9%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 95.76%
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 19.68±0.33
# Total message received: 26800
#  messages received from satellite (% to total messages): 1806 (6.74%)
#  requests received from UE (% to total messages): 4994 (18.63%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 95.75%
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 23.16±0.29
# Total message received: 36786
#  messages received from satellite (% to total messages): 1769 (4.81%)
#  requests received from UE (% to total messages): 5017 (13.64%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 97.11%
# Success Rate: 40000/40000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 25.47±0.27
# Total message received: 47252
#  messages received from satellite (% to total messages): 1976 (4.18%)
#  requests received from UE (% to total messages): 5276 (11.17%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 93.88%
# Success Rate: 50000/50000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 74.68±0.48
# Total message received: 67724
#  messages received from satellite (% to total messages): 4839 (7.15%)
#  requests received from UE (% to total messages): 12885 (19.03%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 94.04%
# Success Rate: 55602/60000 = 92.67%
# Success UE waiting time:
#   # Confidence Interval: 347.02±2.11
# Failure UE waiting time:
#   # Confidence Interval: 442.44±4.48
# Total message received: 122089
#  messages received from satellite (% to total messages): 18510 (15.16%)
#  requests received from UE (% to total messages): 47977 (39.3%)
#    # dropped messages (% to UE messages) 1180 (0.97%)
#    # group messages (% to UE) 94.8%
# Success Rate: 57690/70000 = 82.41428571428571%
# Success UE waiting time:
#   # Confidence Interval: 488.6±2.69
# Failure UE waiting time:
#   # Confidence Interval: 576.7±3.76
# Total message received: 138536
#  messages received from satellite (% to total messages): 22116 (15.96%)
#  requests received from UE (% to total messages): 58730 (42.39%)
#    # dropped messages (% to UE messages) 3480 (2.51%)
#    # group messages (% to UE) 94.65%
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 15.83±0.4
# Total message received: 16520
#  messages received from satellite (% to total messages): 1721 (10.42%)
#  requests received from UE (% to total messages): 4799 (29.05%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 96.21%
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 19.33±0.33
# Total message received: 26656
#  messages received from satellite (% to total messages): 1707 (6.4%)
#  requests received from UE (% to total messages): 4949 (18.57%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 98.26%
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 23.01±0.29
# Total message received: 37110
#  messages received from satellite (% to total messages): 1947 (5.25%)
#  requests received from UE (% to total messages): 5163 (13.91%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 93.49%
# Success Rate: 40000/40000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 25.27±0.27
# Total message received: 47832
#  messages received from satellite (% to total messages): 2258 (4.72%)
#  requests received from UE (% to total messages): 5574 (11.65%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 89.34%
# Success Rate: 50000/50000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 77.85±0.5
# Total message received: 69757
#  messages received from satellite (% to total messages): 5710 (8.19%)
#  requests received from UE (% to total messages): 14047 (20.14%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 89.46%
# Success Rate: 55649/60000 = 92.74833333333333%
# Success UE waiting time:
#   # Confidence Interval: 339.16±2.09
# Failure UE waiting time:
#   # Confidence Interval: 439.89±4.58
# Total message received: 123920
#  messages received from satellite (% to total messages): 19511 (15.74%)
#  requests received from UE (% to total messages): 48760 (39.35%)
#    # dropped messages (% to UE messages) 1290 (1.04%)
#    # group messages (% to UE) 91.04%
# Success Rate: 57868/70000 = 82.66857142857143%
# Success UE waiting time:
#   # Confidence Interval: 480.3±2.66
# Failure UE waiting time:
#   # Confidence Interval: 568.36±3.75
# Total message received: 138172
#  messages received from satellite (% to total messages): 22209 (16.07%)
#  requests received from UE (% to total messages): 58095 (42.05%)
#    # dropped messages (% to UE messages) 3562 (2.58%)
#    # group messages (% to UE) 93.86%
# Success Rate: 10000/10000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 16.1±0.4
# Total message received: 16524
#  messages received from satellite (% to total messages): 1718 (10.4%)
#  requests received from UE (% to total messages): 4806 (29.08%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 96.38%
# Success Rate: 20000/20000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 19.45±0.33
# Total message received: 26842
#  messages received from satellite (% to total messages): 1826 (6.8%)
#  requests received from UE (% to total messages): 5016 (18.69%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 95.39%
# Success Rate: 30000/30000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 22.88±0.29
# Total message received: 36806
#  messages received from satellite (% to total messages): 1778 (4.83%)
#  requests received from UE (% to total messages): 5028 (13.66%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 96.96%
# Success Rate: 40000/40000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 25.59±0.27
# Total message received: 47326
#  messages received from satellite (% to total messages): 1994 (4.21%)
#  requests received from UE (% to total messages): 5332 (11.27%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 94.02%
# Success Rate: 50000/50000 = 100.0%
# Success UE waiting time:
#   # Confidence Interval: 71.16±0.46
# Total message received: 66832
#  messages received from satellite (% to total messages): 4524 (6.77%)
#  requests received from UE (% to total messages): 12308 (18.42%)
#    # dropped messages (% to UE messages) 0 (0.0%)
#    # group messages (% to UE) 95.13%
# Success Rate: 55689/60000 = 92.815%
# Success UE waiting time:
#   # Confidence Interval: 340.67±2.06
# Failure UE waiting time:
#   # Confidence Interval: 436.16±4.54
# Total message received: 120540
#  messages received from satellite (% to total messages): 17818 (14.78%)
#  requests received from UE (% to total messages): 47033 (39.02%)
#    # dropped messages (% to UE messages) 576 (0.48%)
#    # group messages (% to UE) 96.33%
# Success Rate: 57928/70000 = 82.75428571428571%
# Success UE waiting time:
#   # Confidence Interval: 483.36±2.67
# Failure UE waiting time:
#   # Confidence Interval: 564.83±3.73
# Total message received: 136275
#  messages received from satellite (% to total messages): 21155 (15.52%)
#  requests received from UE (% to total messages): 57192 (41.97%)
#    # dropped messages (% to UE messages) 2658 (1.95%)
#    # group messages (% to UE) 96.85%
